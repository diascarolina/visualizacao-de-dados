# %% [markdown]
# <a href="https://colab.research.google.com/github/diascarolina/visualizacao-de-dados/blob/main/M%C3%B3dulo1_Aula2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 2 - Escalas de Cores

# %% [markdown]
# ## Escalas de Cores Quantitativas

# %%
import pandas as pd

# %%
dados = pd.read_csv('https://raw.githubusercontent.com/diascarolina/visualizacao-de-dados/main/dados_seguradora.csv')

# %%
dados.head()
# Out:
#    idade     genero     imc  qtde_filhos eh_fumante   regiao      valores
# 0     19   feminino  27.900            0        sim  sudeste  16884.92400
# 1     18  masculino  33.770            1        nao      sul   1725.55230
# 2     28  masculino  33.000            3        nao      sul   4449.46200
# 3     33  masculino  22.705            0        nao    norte  21984.47061
# 4     32  masculino  28.880            0        nao    norte   3866.85520

# %%
import matplotlib.pyplot as plt

# %%
dados.regiao.value_counts().plot(kind = 'bar', figsize = (10, 6))
plt.title('Regiões')
plt.xlabel('Regiões')
plt.ylabel('Quantidade')
plt.show()

# %%
dados.regiao.value_counts().plot(kind = 'bar', figsize = (10, 6), color = ['r', 'g', 'b', 'y'])
plt.title('Regiões do Brasil', fontsize = 22)
plt.xticks(rotation = 0, fontsize = 15)
plt.yticks(fontsize = 15)
plt.xlabel('Regiões', fontsize = 20)
plt.ylabel('Quantidade', fontsize = 18)
sns.despine()
plt.show()

# %%
plt.figure(figsize = (15, 8))
ax = sns.countplot(x="idade", data=dados, palette = 'Wistia')
plt.title('Distribuição das Idades', fontsize = 15)
plt.xticks(rotation = 0)
plt.xlabel('Idade')
plt.ylabel('Quantidade')
sns.despine()
plt.show()

# %%
dados.regiao.value_counts().plot(kind = 'bar', figsize = (10, 6), color = ['g', 'lightgrey', 'lightgrey', 'lightgrey'])
plt.title('Regiões do Brasil', fontsize = 22)
plt.xticks(rotation = 0, fontsize = 15)
plt.yticks(fontsize = 15)
plt.xlabel('Regiões', fontsize = 20)
plt.ylabel('Quantidade', fontsize = 18)
sns.despine()
plt.show()

# %%
dados.eh_fumante.value_counts().plot(kind = 'bar', figsize = (10, 5), color = ['g', 'r'])
plt.title('É Fumante?', fontsize = 25)
plt.xticks(rotation = 0, fontsize = 20)
plt.yticks(fontsize = 13)
plt.ylabel('Quantidade', fontsize = 15)
sns.despine()
plt.show()
